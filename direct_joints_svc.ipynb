# %% [markdown]
# ## Dataset setup

# %%
dataset_location = "../dataset"
categories = {
    0: "back bowled",
    1: "back too low",
    2: "correct",
    3: "knees inward",
    4: "knees too far forward",
    5: "legs not far",
    6: "legs too far",
    7: "not deep enough",
    8: "too deep enough"
}

# %%
def preprocess_file(df):
    # Normalize data
    pose_mean = df.stack().mean()
    pose_std = df.stack().std()
    df = (df - pose_mean) / pose_std
    return df

# %%
import pickle
import os
import numpy as np
import pandas as pd

import preprocess


def deserialize(file_path):
    print(f"working on {file_path}...")
    with open(file_path, 'rb') as f:
        pose = pickle.load(f)

    return pose


def find_files(folder_dir):
    files = []
    for file in os.listdir(folder_dir):
        if file.endswith(".pose"):
            filepath = os.path.join(folder_dir, file)
            print(f"FOUND FILE: {filepath}")
            if os.path.getsize(filepath) > 0:      
                files.append(os.path.join(folder_dir, file))
            else:
                print(F"ERR: {filepath} EMPTY, skipping...")

    return files


def convert_to_df(pose):
    new_pose = []
    for point in pose:
        new_pose.append([point['x'], point['y'], point['z']])

    return pd.DataFrame(new_pose)


# oops
def find_deserialize_preprocess(folder_dir):
    files = find_files(folder_dir)
    _poses = []
    for file in files:
        _poses.append(preprocess_file(convert_to_df(deserialize(file))))

    print("DONE :O")
    return _poses

# %% [markdown]
# ## Data collection
# This generates X and Y, where each decision Y[i] corresponds to pose X[i]

# %%
import os

data_x = []
data_y = []

for category_id in categories.keys():
    # get path
    category_path = os.path.join(dataset_location, categories[category_id])
    poses = find_deserialize_preprocess(category_path)
    # print(len(poses))
    data_x += poses
    data_y += [category_id] * len(poses)
    # print(len(data_x))
# Out:
# FOUND FILE: ../dataset\back bowled\back_bowled_0.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_1.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_10.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_11.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_12.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_13.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_14.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_15.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_16.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_17.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_18.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_19.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_2.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_20.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_21.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_22.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_23.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_24.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_25.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_26.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_27.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_28.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_29.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_3.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_30.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_31.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_32.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_33.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_34.pose
# ERR: ../dataset\back bowled\back_bowled_34.pose EMPTY, skipping...
# FOUND FILE: ../dataset\back bowled\back_bowled_35.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_36.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_37.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_38.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_39.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_4.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_40.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_41.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_42.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_43.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_44.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_45.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_46.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_47.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_48.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_49.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_5.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_50.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_51.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_52.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_53.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_54.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_55.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_56.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_57.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_58.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_59.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_60.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_62.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_63.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_64.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_65.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_66.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_67.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_68.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_69.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_7.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_70.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_8.pose
# FOUND FILE: ../dataset\back bowled\back_bowled_9.pose
# working on ../dataset\back bowled\back_bowled_0.pose...
# working on ../dataset\back bowled\back_bowled_1.pose...
# working on ../dataset\back bowled\back_bowled_10.pose...
# working on ../dataset\back bowled\back_bowled_11.pose...
# working on ../dataset\back bowled\back_bowled_12.pose...
# working on ../dataset\back bowled\back_bowled_13.pose...
# working on ../dataset\back bowled\back_bowled_14.pose...
# working on ../dataset\back bowled\back_bowled_15.pose...
# working on ../dataset\back bowled\back_bowled_16.pose...
# working on ../dataset\back bowled\back_bowled_17.pose...
# working on ../dataset\back bowled\back_bowled_18.pose...
# working on ../dataset\back bowled\back_bowled_19.pose...
# working on ../dataset\back bowled\back_bowled_2.pose...
# working on ../dataset\back bowled\back_bowled_20.pose...
# working on ../dataset\back bowled\back_bowled_21.pose...
# working on ../dataset\back bowled\back_bowled_22.pose...
# working on ../dataset\back bowled\back_bowled_23.pose...
# working on ../dataset\back bowled\back_bowled_24.pose...
# working on ../dataset\back bowled\back_bowled_25.pose...
# working on ../dataset\back bowled\back_bowled_26.pose...
# working on ../dataset\back bowled\back_bowled_27.pose...
# working on ../dataset\back bowled\back_bowled_28.pose...
# working on ../dataset\back bowled\back_bowled_29.pose...
# working on ../dataset\back bowled\back_bowled_3.pose...
# working on ../dataset\back bowled\back_bowled_30.pose...
# working on ../dataset\back bowled\back_bowled_31.pose...
# working on ../dataset\back bowled\back_bowled_32.pose...
# working on ../dataset\back bowled\back_bowled_33.pose...
# working on ../dataset\back bowled\back_bowled_35.pose...
# working on ../dataset\back bowled\back_bowled_36.pose...
# working on ../dataset\back bowled\back_bowled_37.pose...
# working on ../dataset\back bowled\back_bowled_38.pose...
# working on ../dataset\back bowled\back_bowled_39.pose...
# working on ../dataset\back bowled\back_bowled_4.pose...
# working on ../dataset\back bowled\back_bowled_40.pose...
# working on ../dataset\back bowled\back_bowled_41.pose...
# working on ../dataset\back bowled\back_bowled_42.pose...
# working on ../dataset\back bowled\back_bowled_43.pose...
# working on ../dataset\back bowled\back_bowled_44.pose...
# working on ../dataset\back bowled\back_bowled_45.pose...
# working on ../dataset\back bowled\back_bowled_46.pose...
# working on ../dataset\back bowled\back_bowled_47.pose...
# working on ../dataset\back bowled\back_bowled_48.pose...
# working on ../dataset\back bowled\back_bowled_49.pose...
# working on ../dataset\back bowled\back_bowled_5.pose...
# working on ../dataset\back bowled\back_bowled_50.pose...
# working on ../dataset\back bowled\back_bowled_51.pose...
# working on ../dataset\back bowled\back_bowled_52.pose...
# working on ../dataset\back bowled\back_bowled_53.pose...
# working on ../dataset\back bowled\back_bowled_54.pose...
# working on ../dataset\back bowled\back_bowled_55.pose...
# working on ../dataset\back bowled\back_bowled_56.pose...
# working on ../dataset\back bowled\back_bowled_57.pose...
# working on ../dataset\back bowled\back_bowled_58.pose...
# working on ../dataset\back bowled\back_bowled_59.pose...
# working on ../dataset\back bowled\back_bowled_60.pose...
# working on ../dataset\back bowled\back_bowled_62.pose...
# working on ../dataset\back bowled\back_bowled_63.pose...
# working on ../dataset\back bowled\back_bowled_64.pose...
# working on ../dataset\back bowled\back_bowled_65.pose...
# working on ../dataset\back bowled\back_bowled_66.pose...
# working on ../dataset\back bowled\back_bowled_67.pose...
# working on ../dataset\back bowled\back_bowled_68.pose...
# working on ../dataset\back bowled\back_bowled_69.pose...
# working on ../dataset\back bowled\back_bowled_7.pose...
# working on ../dataset\back bowled\back_bowled_70.pose...
# working on ../dataset\back bowled\back_bowled_8.pose...
# working on ../dataset\back bowled\back_bowled_9.pose...
# DONE :O
# FOUND FILE: ../dataset\back too low\back_too_low_0.pose
# FOUND FILE: ../dataset\back too low\back_too_low_1.pose
# FOUND FILE: ../dataset\back too low\back_too_low_10.pose
# FOUND FILE: ../dataset\back too low\back_too_low_11.pose
# FOUND FILE: ../dataset\back too low\back_too_low_12.pose
# FOUND FILE: ../dataset\back too low\back_too_low_13.pose
# FOUND FILE: ../dataset\back too low\back_too_low_14.pose
# FOUND FILE: ../dataset\back too low\back_too_low_15.pose
# FOUND FILE: ../dataset\back too low\back_too_low_16.pose
# FOUND FILE: ../dataset\back too low\back_too_low_17.pose
# FOUND FILE: ../dataset\back too low\back_too_low_18.pose
# FOUND FILE: ../dataset\back too low\back_too_low_19.pose
# FOUND FILE: ../dataset\back too low\back_too_low_2.pose
# FOUND FILE: ../dataset\back too low\back_too_low_20.pose
# FOUND FILE: ../dataset\back too low\back_too_low_21.pose
# FOUND FILE: ../dataset\back too low\back_too_low_22.pose
# FOUND FILE: ../dataset\back too low\back_too_low_23.pose
# FOUND FILE: ../dataset\back too low\back_too_low_24.pose
# FOUND FILE: ../dataset\back too low\back_too_low_25.pose
# FOUND FILE: ../dataset\back too low\back_too_low_26.pose
# FOUND FILE: ../dataset\back too low\back_too_low_27.pose
# FOUND FILE: ../dataset\back too low\back_too_low_28.pose
# FOUND FILE: ../dataset\back too low\back_too_low_29.pose
# FOUND FILE: ../dataset\back too low\back_too_low_3.pose
# FOUND FILE: ../dataset\back too low\back_too_low_30.pose
# FOUND FILE: ../dataset\back too low\back_too_low_31.pose
# FOUND FILE: ../dataset\back too low\back_too_low_32.pose
# FOUND FILE: ../dataset\back too low\back_too_low_33.pose
# FOUND FILE: ../dataset\back too low\back_too_low_34.pose
# FOUND FILE: ../dataset\back too low\back_too_low_35.pose
# FOUND FILE: ../dataset\back too low\back_too_low_36.pose
# FOUND FILE: ../dataset\back too low\back_too_low_37.pose
# FOUND FILE: ../dataset\back too low\back_too_low_38.pose
# FOUND FILE: ../dataset\back too low\back_too_low_39.pose
# FOUND FILE: ../dataset\back too low\back_too_low_4.pose
# FOUND FILE: ../dataset\back too low\back_too_low_40.pose
# FOUND FILE: ../dataset\back too low\back_too_low_41.pose
# FOUND FILE: ../dataset\back too low\back_too_low_42.pose
# FOUND FILE: ../dataset\back too low\back_too_low_43.pose
# FOUND FILE: ../dataset\back too low\back_too_low_44.pose
# FOUND FILE: ../dataset\back too low\back_too_low_45.pose
# FOUND FILE: ../dataset\back too low\back_too_low_46.pose
# FOUND FILE: ../dataset\back too low\back_too_low_49.pose
# FOUND FILE: ../dataset\back too low\back_too_low_5.pose
# FOUND FILE: ../dataset\back too low\back_too_low_50.pose
# FOUND FILE: ../dataset\back too low\back_too_low_51.pose
# FOUND FILE: ../dataset\back too low\back_too_low_52.pose
# FOUND FILE: ../dataset\back too low\back_too_low_54.pose
# FOUND FILE: ../dataset\back too low\back_too_low_55.pose
# FOUND FILE: ../dataset\back too low\back_too_low_56.pose
# FOUND FILE: ../dataset\back too low\back_too_low_57.pose
# FOUND FILE: ../dataset\back too low\back_too_low_58.pose
# FOUND FILE: ../dataset\back too low\back_too_low_59.pose
# FOUND FILE: ../dataset\back too low\back_too_low_6.pose
# FOUND FILE: ../dataset\back too low\back_too_low_60.pose
# FOUND FILE: ../dataset\back too low\back_too_low_61.pose
# FOUND FILE: ../dataset\back too low\back_too_low_62.pose
# FOUND FILE: ../dataset\back too low\back_too_low_63.pose
# FOUND FILE: ../dataset\back too low\back_too_low_64.pose
# FOUND FILE: ../dataset\back too low\back_too_low_65.pose
# FOUND FILE: ../dataset\back too low\back_too_low_66.pose
# FOUND FILE: ../dataset\back too low\back_too_low_67.pose
# FOUND FILE: ../dataset\back too low\back_too_low_68.pose
# FOUND FILE: ../dataset\back too low\back_too_low_69.pose
# FOUND FILE: ../dataset\back too low\back_too_low_7.pose
# FOUND FILE: ../dataset\back too low\back_too_low_70.pose
# FOUND FILE: ../dataset\back too low\back_too_low_8.pose
# FOUND FILE: ../dataset\back too low\back_too_low_9.pose
# working on ../dataset\back too low\back_too_low_0.pose...
# working on ../dataset\back too low\back_too_low_1.pose...
# working on ../dataset\back too low\back_too_low_10.pose...
# working on ../dataset\back too low\back_too_low_11.pose...
# working on ../dataset\back too low\back_too_low_12.pose...
# working on ../dataset\back too low\back_too_low_13.pose...
# working on ../dataset\back too low\back_too_low_14.pose...
# working on ../dataset\back too low\back_too_low_15.pose...
# working on ../dataset\back too low\back_too_low_16.pose...
# working on ../dataset\back too low\back_too_low_17.pose...
# working on ../dataset\back too low\back_too_low_18.pose...
# working on ../dataset\back too low\back_too_low_19.pose...
# working on ../dataset\back too low\back_too_low_2.pose...
# working on ../dataset\back too low\back_too_low_20.pose...
# working on ../dataset\back too low\back_too_low_21.pose...
# working on ../dataset\back too low\back_too_low_22.pose...
# working on ../dataset\back too low\back_too_low_23.pose...
# working on ../dataset\back too low\back_too_low_24.pose...
# working on ../dataset\back too low\back_too_low_25.pose...
# working on ../dataset\back too low\back_too_low_26.pose...
# working on ../dataset\back too low\back_too_low_27.pose...
# working on ../dataset\back too low\back_too_low_28.pose...
# working on ../dataset\back too low\back_too_low_29.pose...
# working on ../dataset\back too low\back_too_low_3.pose...
# working on ../dataset\back too low\back_too_low_30.pose...
# working on ../dataset\back too low\back_too_low_31.pose...
# working on ../dataset\back too low\back_too_low_32.pose...
# working on ../dataset\back too low\back_too_low_33.pose...
# working on ../dataset\back too low\back_too_low_34.pose...
# working on ../dataset\back too low\back_too_low_35.pose...
# working on ../dataset\back too low\back_too_low_36.pose...
# working on ../dataset\back too low\back_too_low_37.pose...
# working on ../dataset\back too low\back_too_low_38.pose...
# working on ../dataset\back too low\back_too_low_39.pose...
# working on ../dataset\back too low\back_too_low_4.pose...
# working on ../dataset\back too low\back_too_low_40.pose...
# working on ../dataset\back too low\back_too_low_41.pose...
# working on ../dataset\back too low\back_too_low_42.pose...
# working on ../dataset\back too low\back_too_low_43.pose...
# working on ../dataset\back too low\back_too_low_44.pose...
# working on ../dataset\back too low\back_too_low_45.pose...
# working on ../dataset\back too low\back_too_low_46.pose...
# working on ../dataset\back too low\back_too_low_49.pose...
# working on ../dataset\back too low\back_too_low_5.pose...
# working on ../dataset\back too low\back_too_low_50.pose...
# working on ../dataset\back too low\back_too_low_51.pose...
# working on ../dataset\back too low\back_too_low_52.pose...
# working on ../dataset\back too low\back_too_low_54.pose...
# working on ../dataset\back too low\back_too_low_55.pose...
# working on ../dataset\back too low\back_too_low_56.pose...
# working on ../dataset\back too low\back_too_low_57.pose...
# working on ../dataset\back too low\back_too_low_58.pose...
# working on ../dataset\back too low\back_too_low_59.pose...
# working on ../dataset\back too low\back_too_low_6.pose...
# working on ../dataset\back too low\back_too_low_60.pose...
# working on ../dataset\back too low\back_too_low_61.pose...
# working on ../dataset\back too low\back_too_low_62.pose...
# working on ../dataset\back too low\back_too_low_63.pose...
# working on ../dataset\back too low\back_too_low_64.pose...
# working on ../dataset\back too low\back_too_low_65.pose...
# working on ../dataset\back too low\back_too_low_66.pose...
# working on ../dataset\back too low\back_too_low_67.pose...
# working on ../dataset\back too low\back_too_low_68.pose...
# working on ../dataset\back too low\back_too_low_69.pose...
# working on ../dataset\back too low\back_too_low_7.pose...
# working on ../dataset\back too low\back_too_low_70.pose...
# working on ../dataset\back too low\back_too_low_8.pose...
# working on ../dataset\back too low\back_too_low_9.pose...
# DONE :O
# FOUND FILE: ../dataset\correct\correct_0.pose
# FOUND FILE: ../dataset\correct\correct_1.pose
# FOUND FILE: ../dataset\correct\correct_10.pose
# FOUND FILE: ../dataset\correct\correct_11.pose
# FOUND FILE: ../dataset\correct\correct_12.pose
# FOUND FILE: ../dataset\correct\correct_13.pose
# FOUND FILE: ../dataset\correct\correct_14.pose
# FOUND FILE: ../dataset\correct\correct_15.pose
# FOUND FILE: ../dataset\correct\correct_16.pose
# FOUND FILE: ../dataset\correct\correct_17.pose
# FOUND FILE: ../dataset\correct\correct_18.pose
# FOUND FILE: ../dataset\correct\correct_19.pose
# FOUND FILE: ../dataset\correct\correct_2.pose
# FOUND FILE: ../dataset\correct\correct_20.pose
# FOUND FILE: ../dataset\correct\correct_21.pose
# FOUND FILE: ../dataset\correct\correct_22.pose
# FOUND FILE: ../dataset\correct\correct_23.pose
# FOUND FILE: ../dataset\correct\correct_24.pose
# FOUND FILE: ../dataset\correct\correct_25.pose
# FOUND FILE: ../dataset\correct\correct_26.pose
# FOUND FILE: ../dataset\correct\correct_27.pose
# FOUND FILE: ../dataset\correct\correct_28.pose
# FOUND FILE: ../dataset\correct\correct_29.pose
# FOUND FILE: ../dataset\correct\correct_3.pose
# FOUND FILE: ../dataset\correct\correct_30.pose
# FOUND FILE: ../dataset\correct\correct_31.pose
# FOUND FILE: ../dataset\correct\correct_32.pose
# FOUND FILE: ../dataset\correct\correct_33.pose
# FOUND FILE: ../dataset\correct\correct_34.pose
# FOUND FILE: ../dataset\correct\correct_35.pose
# FOUND FILE: ../dataset\correct\correct_36.pose
# FOUND FILE: ../dataset\correct\correct_37.pose
# FOUND FILE: ../dataset\correct\correct_38.pose
# FOUND FILE: ../dataset\correct\correct_39.pose
# FOUND FILE: ../dataset\correct\correct_4.pose
# FOUND FILE: ../dataset\correct\correct_40.pose
# FOUND FILE: ../dataset\correct\correct_41.pose
# FOUND FILE: ../dataset\correct\correct_42.pose
# FOUND FILE: ../dataset\correct\correct_43.pose
# FOUND FILE: ../dataset\correct\correct_44.pose
# FOUND FILE: ../dataset\correct\correct_45.pose
# FOUND FILE: ../dataset\correct\correct_46.pose
# FOUND FILE: ../dataset\correct\correct_47.pose
# FOUND FILE: ../dataset\correct\correct_48.pose
# FOUND FILE: ../dataset\correct\correct_49.pose
# FOUND FILE: ../dataset\correct\correct_5.pose
# FOUND FILE: ../dataset\correct\correct_50.pose
# FOUND FILE: ../dataset\correct\correct_51.pose
# FOUND FILE: ../dataset\correct\correct_52.pose
# FOUND FILE: ../dataset\correct\correct_53.pose
# FOUND FILE: ../dataset\correct\correct_54.pose
# FOUND FILE: ../dataset\correct\correct_55.pose
# FOUND FILE: ../dataset\correct\correct_56.pose
# FOUND FILE: ../dataset\correct\correct_57.pose
# FOUND FILE: ../dataset\correct\correct_58.pose
# FOUND FILE: ../dataset\correct\correct_59.pose
# FOUND FILE: ../dataset\correct\correct_6.pose
# FOUND FILE: ../dataset\correct\correct_60.pose
# FOUND FILE: ../dataset\correct\correct_61.pose
# FOUND FILE: ../dataset\correct\correct_62.pose
# FOUND FILE: ../dataset\correct\correct_63.pose
# FOUND FILE: ../dataset\correct\correct_64.pose
# FOUND FILE: ../dataset\correct\correct_65.pose
# FOUND FILE: ../dataset\correct\correct_66.pose
# FOUND FILE: ../dataset\correct\correct_67.pose
# FOUND FILE: ../dataset\correct\correct_68.pose
# FOUND FILE: ../dataset\correct\correct_69.pose
# FOUND FILE: ../dataset\correct\correct_7.pose
# FOUND FILE: ../dataset\correct\correct_70.pose
# FOUND FILE: ../dataset\correct\correct_71.pose
# FOUND FILE: ../dataset\correct\correct_72.pose
# FOUND FILE: ../dataset\correct\correct_73.pose
# FOUND FILE: ../dataset\correct\correct_8.pose
# FOUND FILE: ../dataset\correct\correct_9.pose
# working on ../dataset\correct\correct_0.pose...
# working on ../dataset\correct\correct_1.pose...
# working on ../dataset\correct\correct_10.pose...
# working on ../dataset\correct\correct_11.pose...
# working on ../dataset\correct\correct_12.pose...
# working on ../dataset\correct\correct_13.pose...
# working on ../dataset\correct\correct_14.pose...
# working on ../dataset\correct\correct_15.pose...
# working on ../dataset\correct\correct_16.pose...
# working on ../dataset\correct\correct_17.pose...
# working on ../dataset\correct\correct_18.pose...
# working on ../dataset\correct\correct_19.pose...
# working on ../dataset\correct\correct_2.pose...
# working on ../dataset\correct\correct_20.pose...
# working on ../dataset\correct\correct_21.pose...
# working on ../dataset\correct\correct_22.pose...
# working on ../dataset\correct\correct_23.pose...
# working on ../dataset\correct\correct_24.pose...
# working on ../dataset\correct\correct_25.pose...
# working on ../dataset\correct\correct_26.pose...
# working on ../dataset\correct\correct_27.pose...
# working on ../dataset\correct\correct_28.pose...
# working on ../dataset\correct\correct_29.pose...
# working on ../dataset\correct\correct_3.pose...
# working on ../dataset\correct\correct_30.pose...
# working on ../dataset\correct\correct_31.pose...
# working on ../dataset\correct\correct_32.pose...
# working on ../dataset\correct\correct_33.pose...
# working on ../dataset\correct\correct_34.pose...
# working on ../dataset\correct\correct_35.pose...
# working on ../dataset\correct\correct_36.pose...
# working on ../dataset\correct\correct_37.pose...
# working on ../dataset\correct\correct_38.pose...
# working on ../dataset\correct\correct_39.pose...
# working on ../dataset\correct\correct_4.pose...
# working on ../dataset\correct\correct_40.pose...
# working on ../dataset\correct\correct_41.pose...
# working on ../dataset\correct\correct_42.pose...
# working on ../dataset\correct\correct_43.pose...
# working on ../dataset\correct\correct_44.pose...
# working on ../dataset\correct\correct_45.pose...
# working on ../dataset\correct\correct_46.pose...
# working on ../dataset\correct\correct_47.pose...
# working on ../dataset\correct\correct_48.pose...
# working on ../dataset\correct\correct_49.pose...
# working on ../dataset\correct\correct_5.pose...
# working on ../dataset\correct\correct_50.pose...
# working on ../dataset\correct\correct_51.pose...
# working on ../dataset\correct\correct_52.pose...
# working on ../dataset\correct\correct_53.pose...
# working on ../dataset\correct\correct_54.pose...
# working on ../dataset\correct\correct_55.pose...
# working on ../dataset\correct\correct_56.pose...
# working on ../dataset\correct\correct_57.pose...
# working on ../dataset\correct\correct_58.pose...
# working on ../dataset\correct\correct_59.pose...
# working on ../dataset\correct\correct_6.pose...
# working on ../dataset\correct\correct_60.pose...
# working on ../dataset\correct\correct_61.pose...
# working on ../dataset\correct\correct_62.pose...
# working on ../dataset\correct\correct_63.pose...
# working on ../dataset\correct\correct_64.pose...
# working on ../dataset\correct\correct_65.pose...
# working on ../dataset\correct\correct_66.pose...
# working on ../dataset\correct\correct_67.pose...
# working on ../dataset\correct\correct_68.pose...
# working on ../dataset\correct\correct_69.pose...
# working on ../dataset\correct\correct_7.pose...
# working on ../dataset\correct\correct_70.pose...
# working on ../dataset\correct\correct_71.pose...
# working on ../dataset\correct\correct_72.pose...
# working on ../dataset\correct\correct_73.pose...
# working on ../dataset\correct\correct_8.pose...
# working on ../dataset\correct\correct_9.pose...
# DONE :O
# FOUND FILE: ../dataset\knees inward\knees_inward_1.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_10.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_11.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_12.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_13.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_14.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_15.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_16.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_17.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_18.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_19.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_2.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_20.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_21.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_22.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_23.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_24.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_25.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_26.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_27.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_28.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_29.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_3.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_30.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_31.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_32.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_33.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_34.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_35.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_36.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_37.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_38.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_39.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_4.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_40.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_41.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_42.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_43.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_44.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_45.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_46.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_47.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_48.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_49.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_5.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_50.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_51.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_52.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_53.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_54.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_55.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_56.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_57.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_58.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_59.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_6.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_60.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_61.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_62.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_63.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_64.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_65.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_66.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_67.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_68.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_69.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_7.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_70.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_71.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_72.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_8.pose
# FOUND FILE: ../dataset\knees inward\knees_inward_9.pose
# working on ../dataset\knees inward\knees_inward_1.pose...
# working on ../dataset\knees inward\knees_inward_10.pose...
# working on ../dataset\knees inward\knees_inward_11.pose...
# working on ../dataset\knees inward\knees_inward_12.pose...
# working on ../dataset\knees inward\knees_inward_13.pose...
# working on ../dataset\knees inward\knees_inward_14.pose...
# working on ../dataset\knees inward\knees_inward_15.pose...
# working on ../dataset\knees inward\knees_inward_16.pose...
# working on ../dataset\knees inward\knees_inward_17.pose...
# working on ../dataset\knees inward\knees_inward_18.pose...
# working on ../dataset\knees inward\knees_inward_19.pose...
# working on ../dataset\knees inward\knees_inward_2.pose...
# working on ../dataset\knees inward\knees_inward_20.pose...
# working on ../dataset\knees inward\knees_inward_21.pose...
# working on ../dataset\knees inward\knees_inward_22.pose...
# working on ../dataset\knees inward\knees_inward_23.pose...
# working on ../dataset\knees inward\knees_inward_24.pose...
# working on ../dataset\knees inward\knees_inward_25.pose...
# working on ../dataset\knees inward\knees_inward_26.pose...
# working on ../dataset\knees inward\knees_inward_27.pose...
# working on ../dataset\knees inward\knees_inward_28.pose...
# working on ../dataset\knees inward\knees_inward_29.pose...
# working on ../dataset\knees inward\knees_inward_3.pose...
# working on ../dataset\knees inward\knees_inward_30.pose...
# working on ../dataset\knees inward\knees_inward_31.pose...
# working on ../dataset\knees inward\knees_inward_32.pose...
# working on ../dataset\knees inward\knees_inward_33.pose...
# working on ../dataset\knees inward\knees_inward_34.pose...
# working on ../dataset\knees inward\knees_inward_35.pose...
# working on ../dataset\knees inward\knees_inward_36.pose...
# working on ../dataset\knees inward\knees_inward_37.pose...
# working on ../dataset\knees inward\knees_inward_38.pose...
# working on ../dataset\knees inward\knees_inward_39.pose...
# working on ../dataset\knees inward\knees_inward_4.pose...
# working on ../dataset\knees inward\knees_inward_40.pose...
# working on ../dataset\knees inward\knees_inward_41.pose...
# working on ../dataset\knees inward\knees_inward_42.pose...
# working on ../dataset\knees inward\knees_inward_43.pose...
# working on ../dataset\knees inward\knees_inward_44.pose...
# working on ../dataset\knees inward\knees_inward_45.pose...
# working on ../dataset\knees inward\knees_inward_46.pose...
# working on ../dataset\knees inward\knees_inward_47.pose...
# working on ../dataset\knees inward\knees_inward_48.pose...
# working on ../dataset\knees inward\knees_inward_49.pose...
# working on ../dataset\knees inward\knees_inward_5.pose...
# working on ../dataset\knees inward\knees_inward_50.pose...
# working on ../dataset\knees inward\knees_inward_51.pose...
# working on ../dataset\knees inward\knees_inward_52.pose...
# working on ../dataset\knees inward\knees_inward_53.pose...
# working on ../dataset\knees inward\knees_inward_54.pose...
# working on ../dataset\knees inward\knees_inward_55.pose...
# working on ../dataset\knees inward\knees_inward_56.pose...
# working on ../dataset\knees inward\knees_inward_57.pose...
# working on ../dataset\knees inward\knees_inward_58.pose...
# working on ../dataset\knees inward\knees_inward_59.pose...
# working on ../dataset\knees inward\knees_inward_6.pose...
# working on ../dataset\knees inward\knees_inward_60.pose...
# working on ../dataset\knees inward\knees_inward_61.pose...
# working on ../dataset\knees inward\knees_inward_62.pose...
# working on ../dataset\knees inward\knees_inward_63.pose...
# working on ../dataset\knees inward\knees_inward_64.pose...
# working on ../dataset\knees inward\knees_inward_65.pose...
# working on ../dataset\knees inward\knees_inward_66.pose...
# working on ../dataset\knees inward\knees_inward_67.pose...
# working on ../dataset\knees inward\knees_inward_68.pose...
# working on ../dataset\knees inward\knees_inward_69.pose...
# working on ../dataset\knees inward\knees_inward_7.pose...
# working on ../dataset\knees inward\knees_inward_70.pose...
# working on ../dataset\knees inward\knees_inward_71.pose...
# working on ../dataset\knees inward\knees_inward_72.pose...
# working on ../dataset\knees inward\knees_inward_8.pose...
# working on ../dataset\knees inward\knees_inward_9.pose...
# DONE :O
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_1.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_10.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_11.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_12.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_13.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_14.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_15.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_16.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_17.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_18.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_19.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_2.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_20.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_21.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_22.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_23.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_24.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_25.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_26.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_27.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_28.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_29.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_3.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_30.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_31.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_32.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_33.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_34.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_35.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_36.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_37.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_38.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_39.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_4.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_40.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_41.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_42.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_43.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_44.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_45.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_46.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_47.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_48.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_49.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_50.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_51.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_52.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_53.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_54.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_55.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_56.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_57.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_58.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_59.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_6.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_60.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_61.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_62.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_63.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_64.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_65.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_66.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_67.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_68.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_69.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_7.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_70.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_71.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_72.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_73.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_74.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_75.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_76.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_77.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_78.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_79.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_8.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_80.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_81.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_82.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_83.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_84.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_85.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_86.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_87.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_88.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_89.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_9.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_90.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_91.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_92.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_93.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_94.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_95.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_96.pose
# FOUND FILE: ../dataset\knees too far forward\knees_too_far_forward_97.pose
# working on ../dataset\knees too far forward\knees_too_far_forward_1.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_10.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_11.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_12.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_13.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_14.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_15.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_16.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_17.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_18.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_19.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_2.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_20.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_21.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_22.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_23.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_24.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_25.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_26.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_27.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_28.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_29.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_3.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_30.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_31.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_32.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_33.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_34.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_35.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_36.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_37.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_38.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_39.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_4.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_40.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_41.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_42.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_43.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_44.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_45.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_46.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_47.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_48.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_49.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_50.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_51.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_52.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_53.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_54.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_55.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_56.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_57.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_58.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_59.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_6.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_60.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_61.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_62.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_63.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_64.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_65.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_66.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_67.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_68.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_69.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_7.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_70.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_71.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_72.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_73.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_74.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_75.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_76.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_77.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_78.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_79.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_8.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_80.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_81.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_82.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_83.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_84.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_85.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_86.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_87.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_88.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_89.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_9.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_90.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_91.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_92.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_93.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_94.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_95.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_96.pose...
# working on ../dataset\knees too far forward\knees_too_far_forward_97.pose...
# DONE :O
# FOUND FILE: ../dataset\legs not far\knees_not_far_0.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_1.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_10.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_11.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_12.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_13.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_14.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_15.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_16.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_17.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_18.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_19.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_2.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_20.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_21.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_22.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_23.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_24.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_25.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_26.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_27.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_28.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_29.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_3.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_30.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_31.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_32.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_33.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_34.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_35.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_36.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_37.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_38.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_39.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_4.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_40.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_41.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_42.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_43.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_44.pose
# FOUND FILE: ../dataset\legs not far\knees_not_far_45.pose
# ...
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_51.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_52.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_53.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_54.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_55.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_56.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_57.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_58.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_59.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_60.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_61.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_62.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_63.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_64.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_65.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_66.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_67.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_68.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_69.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_7.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_70.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_71.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_72.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_8.pose
# FOUND FILE: ../dataset\not deep enough\not_deep_enough_9.pose
# working on ../dataset\not deep enough\not_deep_enough_0.pose...
# working on ../dataset\not deep enough\not_deep_enough_1.pose...
# working on ../dataset\not deep enough\not_deep_enough_10.pose...
# working on ../dataset\not deep enough\not_deep_enough_11.pose...
# working on ../dataset\not deep enough\not_deep_enough_12.pose...
# working on ../dataset\not deep enough\not_deep_enough_13.pose...
# working on ../dataset\not deep enough\not_deep_enough_14.pose...
# working on ../dataset\not deep enough\not_deep_enough_15.pose...
# working on ../dataset\not deep enough\not_deep_enough_16.pose...
# working on ../dataset\not deep enough\not_deep_enough_17.pose...
# working on ../dataset\not deep enough\not_deep_enough_18.pose...
# working on ../dataset\not deep enough\not_deep_enough_19.pose...
# working on ../dataset\not deep enough\not_deep_enough_2.pose...
# working on ../dataset\not deep enough\not_deep_enough_20.pose...
# working on ../dataset\not deep enough\not_deep_enough_21.pose...
# working on ../dataset\not deep enough\not_deep_enough_22.pose...
# working on ../dataset\not deep enough\not_deep_enough_23.pose...
# working on ../dataset\not deep enough\not_deep_enough_24.pose...
# working on ../dataset\not deep enough\not_deep_enough_25.pose...
# working on ../dataset\not deep enough\not_deep_enough_26.pose...
# working on ../dataset\not deep enough\not_deep_enough_27.pose...
# working on ../dataset\not deep enough\not_deep_enough_28.pose...
# working on ../dataset\not deep enough\not_deep_enough_29.pose...
# working on ../dataset\not deep enough\not_deep_enough_3.pose...
# working on ../dataset\not deep enough\not_deep_enough_30.pose...
# working on ../dataset\not deep enough\not_deep_enough_31.pose...
# working on ../dataset\not deep enough\not_deep_enough_32.pose...
# working on ../dataset\not deep enough\not_deep_enough_33.pose...
# working on ../dataset\not deep enough\not_deep_enough_34.pose...
# working on ../dataset\not deep enough\not_deep_enough_35.pose...
# working on ../dataset\not deep enough\not_deep_enough_36.pose...
# working on ../dataset\not deep enough\not_deep_enough_37.pose...
# working on ../dataset\not deep enough\not_deep_enough_38.pose...
# working on ../dataset\not deep enough\not_deep_enough_39.pose...
# working on ../dataset\not deep enough\not_deep_enough_4.pose...
# working on ../dataset\not deep enough\not_deep_enough_40.pose...
# working on ../dataset\not deep enough\not_deep_enough_41.pose...
# working on ../dataset\not deep enough\not_deep_enough_42.pose...
# working on ../dataset\not deep enough\not_deep_enough_43.pose...
# working on ../dataset\not deep enough\not_deep_enough_44.pose...
# working on ../dataset\not deep enough\not_deep_enough_45.pose...
# working on ../dataset\not deep enough\not_deep_enough_46.pose...
# working on ../dataset\not deep enough\not_deep_enough_47.pose...
# working on ../dataset\not deep enough\not_deep_enough_48.pose...
# working on ../dataset\not deep enough\not_deep_enough_49.pose...
# working on ../dataset\not deep enough\not_deep_enough_5.pose...
# working on ../dataset\not deep enough\not_deep_enough_50.pose...
# working on ../dataset\not deep enough\not_deep_enough_51.pose...
# working on ../dataset\not deep enough\not_deep_enough_52.pose...
# working on ../dataset\not deep enough\not_deep_enough_53.pose...
# working on ../dataset\not deep enough\not_deep_enough_54.pose...
# working on ../dataset\not deep enough\not_deep_enough_55.pose...
# working on ../dataset\not deep enough\not_deep_enough_56.pose...
# working on ../dataset\not deep enough\not_deep_enough_57.pose...
# working on ../dataset\not deep enough\not_deep_enough_58.pose...
# working on ../dataset\not deep enough\not_deep_enough_59.pose...
# working on ../dataset\not deep enough\not_deep_enough_60.pose...
# working on ../dataset\not deep enough\not_deep_enough_61.pose...
# working on ../dataset\not deep enough\not_deep_enough_62.pose...
# working on ../dataset\not deep enough\not_deep_enough_63.pose...
# working on ../dataset\not deep enough\not_deep_enough_64.pose...
# working on ../dataset\not deep enough\not_deep_enough_65.pose...
# working on ../dataset\not deep enough\not_deep_enough_66.pose...
# working on ../dataset\not deep enough\not_deep_enough_67.pose...
# working on ../dataset\not deep enough\not_deep_enough_68.pose...
# working on ../dataset\not deep enough\not_deep_enough_69.pose...
# working on ../dataset\not deep enough\not_deep_enough_7.pose...
# working on ../dataset\not deep enough\not_deep_enough_70.pose...
# working on ../dataset\not deep enough\not_deep_enough_71.pose...
# working on ../dataset\not deep enough\not_deep_enough_72.pose...
# working on ../dataset\not deep enough\not_deep_enough_8.pose...
# working on ../dataset\not deep enough\not_deep_enough_9.pose...
# DONE :O
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_0.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_1.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_10.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_11.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_12.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_13.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_14.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_15.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_16.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_17.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_18.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_19.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_2.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_20.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_21.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_22.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_23.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_24.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_25.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_26.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_27.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_28.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_29.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_3.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_30.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_31.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_32.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_33.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_34.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_35.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_36.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_37.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_38.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_39.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_4.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_40.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_41.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_42.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_43.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_44.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_45.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_46.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_47.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_48.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_49.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_5.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_51.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_52.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_53.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_54.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_55.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_56.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_57.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_58.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_59.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_6.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_60.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_61.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_62.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_63.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_64.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_65.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_66.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_67.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_68.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_69.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_7.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_70.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_71.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_72.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_73.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_74.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_75.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_76.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_8.pose
# FOUND FILE: ../dataset\too deep enough\too_deep_enough_9.pose
# working on ../dataset\too deep enough\too_deep_enough_0.pose...
# working on ../dataset\too deep enough\too_deep_enough_1.pose...
# working on ../dataset\too deep enough\too_deep_enough_10.pose...
# working on ../dataset\too deep enough\too_deep_enough_11.pose...
# working on ../dataset\too deep enough\too_deep_enough_12.pose...
# working on ../dataset\too deep enough\too_deep_enough_13.pose...
# working on ../dataset\too deep enough\too_deep_enough_14.pose...
# working on ../dataset\too deep enough\too_deep_enough_15.pose...
# working on ../dataset\too deep enough\too_deep_enough_16.pose...
# working on ../dataset\too deep enough\too_deep_enough_17.pose...
# working on ../dataset\too deep enough\too_deep_enough_18.pose...
# working on ../dataset\too deep enough\too_deep_enough_19.pose...
# working on ../dataset\too deep enough\too_deep_enough_2.pose...
# working on ../dataset\too deep enough\too_deep_enough_20.pose...
# working on ../dataset\too deep enough\too_deep_enough_21.pose...
# working on ../dataset\too deep enough\too_deep_enough_22.pose...
# working on ../dataset\too deep enough\too_deep_enough_23.pose...
# working on ../dataset\too deep enough\too_deep_enough_24.pose...
# working on ../dataset\too deep enough\too_deep_enough_25.pose...
# working on ../dataset\too deep enough\too_deep_enough_26.pose...
# working on ../dataset\too deep enough\too_deep_enough_27.pose...
# working on ../dataset\too deep enough\too_deep_enough_28.pose...
# working on ../dataset\too deep enough\too_deep_enough_29.pose...
# working on ../dataset\too deep enough\too_deep_enough_3.pose...
# working on ../dataset\too deep enough\too_deep_enough_30.pose...
# working on ../dataset\too deep enough\too_deep_enough_31.pose...
# working on ../dataset\too deep enough\too_deep_enough_32.pose...
# working on ../dataset\too deep enough\too_deep_enough_33.pose...
# working on ../dataset\too deep enough\too_deep_enough_34.pose...
# working on ../dataset\too deep enough\too_deep_enough_35.pose...
# working on ../dataset\too deep enough\too_deep_enough_36.pose...
# working on ../dataset\too deep enough\too_deep_enough_37.pose...
# working on ../dataset\too deep enough\too_deep_enough_38.pose...
# working on ../dataset\too deep enough\too_deep_enough_39.pose...
# working on ../dataset\too deep enough\too_deep_enough_4.pose...
# working on ../dataset\too deep enough\too_deep_enough_40.pose...
# working on ../dataset\too deep enough\too_deep_enough_41.pose...
# working on ../dataset\too deep enough\too_deep_enough_42.pose...
# working on ../dataset\too deep enough\too_deep_enough_43.pose...
# working on ../dataset\too deep enough\too_deep_enough_44.pose...
# working on ../dataset\too deep enough\too_deep_enough_45.pose...
# working on ../dataset\too deep enough\too_deep_enough_46.pose...
# working on ../dataset\too deep enough\too_deep_enough_47.pose...
# working on ../dataset\too deep enough\too_deep_enough_48.pose...
# working on ../dataset\too deep enough\too_deep_enough_49.pose...
# working on ../dataset\too deep enough\too_deep_enough_5.pose...
# working on ../dataset\too deep enough\too_deep_enough_51.pose...
# working on ../dataset\too deep enough\too_deep_enough_52.pose...
# working on ../dataset\too deep enough\too_deep_enough_53.pose...
# working on ../dataset\too deep enough\too_deep_enough_54.pose...
# working on ../dataset\too deep enough\too_deep_enough_55.pose...
# working on ../dataset\too deep enough\too_deep_enough_56.pose...
# working on ../dataset\too deep enough\too_deep_enough_57.pose...
# working on ../dataset\too deep enough\too_deep_enough_58.pose...
# working on ../dataset\too deep enough\too_deep_enough_59.pose...
# working on ../dataset\too deep enough\too_deep_enough_6.pose...
# working on ../dataset\too deep enough\too_deep_enough_60.pose...
# working on ../dataset\too deep enough\too_deep_enough_61.pose...
# working on ../dataset\too deep enough\too_deep_enough_62.pose...
# working on ../dataset\too deep enough\too_deep_enough_63.pose...
# working on ../dataset\too deep enough\too_deep_enough_64.pose...
# working on ../dataset\too deep enough\too_deep_enough_65.pose...
# working on ../dataset\too deep enough\too_deep_enough_66.pose...
# working on ../dataset\too deep enough\too_deep_enough_67.pose...
# working on ../dataset\too deep enough\too_deep_enough_68.pose...
# working on ../dataset\too deep enough\too_deep_enough_69.pose...
# working on ../dataset\too deep enough\too_deep_enough_7.pose...
# working on ../dataset\too deep enough\too_deep_enough_70.pose...
# working on ../dataset\too deep enough\too_deep_enough_71.pose...
# working on ../dataset\too deep enough\too_deep_enough_72.pose...
# working on ../dataset\too deep enough\too_deep_enough_73.pose...
# working on ../dataset\too deep enough\too_deep_enough_74.pose...
# working on ../dataset\too deep enough\too_deep_enough_75.pose...
# working on ../dataset\too deep enough\too_deep_enough_76.pose...
# working on ../dataset\too deep enough\too_deep_enough_8.pose...
# working on ../dataset\too deep enough\too_deep_enough_9.pose...
# DONE :O

# %% [markdown]
# # Training
# 000OooOOoo0oOoo0ooo
# Using SVM right now

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
# Shuffle and split data
data_x = np.array(data_x)
data_y = np.array(data_y)

# reshape into 2d
nsamples, nx, ny = data_x.shape
data_x_reshaped = data_x.reshape((nsamples,nx*ny))

print(len(data_x))
# print(data_x)
print(len(data_y))
x_train, x_test, y_train, y_test = train_test_split(data_x_reshaped, data_y, test_size=0.33, shuffle=True)

clf = svm.LinearSVC(dual='auto', max_iter=80000)
clf.fit(x_train, y_train)
# Out:
# 688
# 688
# LinearSVC(dual='auto', max_iter=80000)

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score

y_pred = clf.predict(x_test)
print("R^2     :", r2_score(y_test, y_pred))
print("MAE     :", mean_absolute_error(y_test,y_pred))
print("RMSE    :",np.sqrt(mean_squared_error(y_test, y_pred)))
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# R^2     : 0.49680948040109385
# MAE     : 0.7368421052631579
# RMSE    : 1.796683103788366
# Accuracy: 0.7675438596491229
